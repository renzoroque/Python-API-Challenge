# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import json

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "Output_Data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 629

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
full_url = url + "appid=" + weather_api_key + "&q=" + cities[0] + "&units=imperial"
response = requests.get(full_url).json()
response
# Out:
# {'coord': {'lon': 4.38, 'lat': 12.22},
#  'weather': [{'id': 804,
#    'main': 'Clouds',
#    'description': 'overcast clouds',
#    'icon': '04n'}],
#  'base': 'stations',
#  'main': {'temp': 72.09,
#   'feels_like': 73.26,
#   'temp_min': 72.09,
#   'temp_max': 72.09,
#   'pressure': 1015,
#   'humidity': 88,
#   'sea_level': 1015,
#   'grnd_level': 991},
#  'visibility': 10000,
#  'wind': {'speed': 10.02, 'deg': 175},
#  'clouds': {'all': 100},
#  'dt': 1596833027,
#  'sys': {'country': 'NG', 'sunrise': 1596778210, 'sunset': 1596823578},
#  'timezone': 3600,
#  'id': 2336237,
#  'name': 'Jega',
#  'cod': 200}

# %%
CityName = []
Latitude = []
Longitude = []
MaxTemp = []
Humidity = []
Cloudiness = []
WindSpeed = []
Country= []
Date = []

for city in cities:
    full_url = url + "appid=" + weather_api_key + "&q=" + city + "&units=imperial"
    response = requests.get(full_url).json()
    try:
        CityName.append(response["name"])
        Latitude.append(response["coord"]["lat"])
        Longitude.append(response["coord"]["lon"])
        MaxTemp.append(response["main"]["temp_max"])
        Humidity.append(response["main"]["humidity"])
        Cloudiness.append(response["clouds"]["all"])
        WindSpeed.append(response["wind"]["speed"])
        Country.append(response["sys"]["country"])
        Date.append(response["dt"])
        print(f'Processing records for: {city}')
                     
        time.sleep(.5)
        
    except:
        print("An exception has occurred")
# Out:
# Processing records for: jega
# Processing records for: ancud
# An exception has occurred
# An exception has occurred
# Processing records for: rivadavia
# Processing records for: bengkulu
# Processing records for: rikitea
# Processing records for: tuktoyaktuk
# Processing records for: warrnambool
# Processing records for: jumla
# Processing records for: new norfolk
# Processing records for: coihaique
# An exception has occurred
# Processing records for: bredasdorp
# Processing records for: great bend
# An exception has occurred
# Processing records for: castro
# Processing records for: dikson
# Processing records for: mar del plata
# Processing records for: lavrentiya
# Processing records for: sidney
# Processing records for: fortuna
# An exception has occurred
# Processing records for: sao miguel do araguaia
# Processing records for: atuona
# Processing records for: iqaluit
# Processing records for: krasnoarmeysk
# Processing records for: vao
# Processing records for: balaipungut
# Processing records for: saint-philippe
# Processing records for: nanakuli
# An exception has occurred
# Processing records for: puerto del rosario
# Processing records for: ponta do sol
# Processing records for: padang
# Processing records for: seoul
# Processing records for: doctor juan leon mallorquin
# Processing records for: upernavik
# Processing records for: norman wells
# Processing records for: cherskiy
# An exception has occurred
# Processing records for: araguaina
# Processing records for: hobart
# Processing records for: faya
# Processing records for: hobyo
# Processing records for: kapaa
# Processing records for: punta arenas
# Processing records for: lebu
# Processing records for: bluff
# Processing records for: coquimbo
# An exception has occurred
# Processing records for: vaini
# Processing records for: nikolskoye
# Processing records for: butaritari
# Processing records for: cape town
# Processing records for: aksaray
# Processing records for: chokurdakh
# Processing records for: khatanga
# Processing records for: quatre cocos
# An exception has occurred
# Processing records for: kysyl-syr
# Processing records for: galle
# Processing records for: east london
# Processing records for: laguna
# Processing records for: busselton
# An exception has occurred
# Processing records for: saldanha
# Processing records for: zhezkazgan
# Processing records for: port alfred
# Processing records for: derzhavinsk
# Processing records for: albany
# Processing records for: pleasanton
# Processing records for: hermanus
# An exception has occurred
# Processing records for: tasiilaq
# Processing records for: minusinsk
# Processing records for: yenagoa
# Processing records for: puerto montt
# Processing records for: maragogi
# Processing records for: georgetown
# Processing records for: lompoc
# Processing records for: jamestown
# Processing records for: chapais
# Processing records for: yerbogachen
# Processing records for: port keats
# Processing records for: port elizabeth
# Processing records for: magadan
# Processing records for: mataura
# Processing records for: kahului
# Processing records for: japura
# Processing records for: fasa
# Processing records for: abu samrah
# An exception has occurred
# Processing records for: marsh harbour
# Processing records for: axim
# Processing records for: hasaki
# Processing records for: sorland
# Processing records for: goderich
# Processing records for: saint george
# Processing records for: belvedere marittimo
# Processing records for: alekseyevsk
# Processing records for: horki
# Processing records for: aklavik
# Processing records for: san cristobal
# Processing records for: ushuaia
# Processing records for: fort morgan
# Processing records for: muros
# An exception has occurred
# Processing records for: petropavlovsk-kamchatskiy
# Processing records for: charters towers
# Processing records for: nuuk
# Processing records for: avera
# Processing records for: linkou
# Processing records for: medeiros neto
# Processing records for: cookeville
# Processing records for: sacramento
# Processing records for: narsaq
# Processing records for: clyde river
# An exception has occurred
# Processing records for: moa
# Processing records for: luderitz
# Processing records for: hay river
# Processing records for: makhachkala
# Processing records for: bambous virieux
# An exception has occurred
# Processing records for: eniwa
# Processing records for: paita
# Processing records for: ulladulla
# Processing records for: culebra
# Processing records for: tevriz
# Processing records for: makakilo city
# Processing records for: booue
# Processing records for: port lincoln
# Processing records for: newport
# Processing records for: malanje
# Processing records for: grindavik
# Processing records for: lookan
# Processing records for: pangody
# Processing records for: avarua
# An exception has occurred
# Processing records for: okha
# Processing records for: macamic
# Processing records for: lircay
# Processing records for: ilulissat
# Processing records for: caravelas
# Processing records for: west odessa
# Processing records for: codrington
# Processing records for: ambanja
# Processing records for: scarborough
# Processing records for: sayyan
# Processing records for: shumskiy
# Processing records for: airai
# Processing records for: thompson
# An exception has occurred
# Processing records for: mango
# Processing records for: aitape
# An exception has occurred
# An exception has occurred
# Processing records for: duluth
# Processing records for: porto torres
# Processing records for: rio gallegos
# Processing records for: tateyama
# Processing records for: pak phanang
# Processing records for: mahebourg
# An exception has occurred
# Processing records for: carnarvon
# Processing records for: puerto ayora
# Processing records for: margate
# Processing records for: wetaskiwin
# Processing records for: katsuura
# Processing records for: moba
# Processing records for: mount hagen
# Processing records for: arraial do cabo
# An exception has occurred
# Processing records for: marawi
# Processing records for: tuatapere
# Processing records for: linhares
# An exception has occurred
# Processing records for: college
# Processing records for: baykit
# Processing records for: tukrah
# Processing records for: kalmunai
# Processing records for: terrace bay
# Processing records for: saint anthony
# Processing records for: corrente
# Processing records for: nome
# Processing records for: lata
# Processing records for: orumiyeh
# Processing records for: banda aceh
# Processing records for: miri
# Processing records for: aseri
# Processing records for: bethel
# Processing records for: yakeshi
# Processing records for: zamora
# Processing records for: puri
# Processing records for: pailon
# Processing records for: xique-xique
# Processing records for: sambava
# An exception has occurred
# Processing records for: nanortalik
# An exception has occurred
# Processing records for: san pedro
# Processing records for: kloulklubed
# Processing records for: houston
# Processing records for: miracema do tocantins
# Processing records for: ambon
# Processing records for: ribeira grande
# Processing records for: baft
# Processing records for: henties bay
# Processing records for: atar
# Processing records for: tiksi
# Processing records for: kurumkan
# Processing records for: sao caetano de odivelas
# Processing records for: esperance
# Processing records for: yellowknife
# Processing records for: tornio
# Processing records for: caceres
# Processing records for: san miguel
# Processing records for: hithadhoo
# An exception has occurred
# Processing records for: shimoda
# Processing records for: tromso
# Processing records for: barrow
# Processing records for: new iberia
# Processing records for: dawlatabad
# Processing records for: soritor
# Processing records for: palora
# Processing records for: ahipara
# Processing records for: nalobikha
# Processing records for: hit
# Processing records for: richards bay
# Processing records for: ostrovnoy
# Processing records for: geraldton
# Processing records for: mega
# Processing records for: poum
# Processing records for: saint-francois
# Processing records for: emerald
# Processing records for: boende
# Processing records for: oussouye
# Processing records for: mount gambier
# Processing records for: jardim
# Processing records for: hauge
# Processing records for: tynda
# Processing records for: diglur
# Processing records for: dauriya
# Processing records for: beringovskiy
# Processing records for: laiyang
# Processing records for: petatlan
# Processing records for: clarence town
# Processing records for: severo-kurilsk
# Processing records for: kanke
# Processing records for: haines junction
# Processing records for: isangel
# Processing records for: san quintin
# Processing records for: alyangula
# Processing records for: cockburn town
# Processing records for: berlevag
# Processing records for: celestun
# An exception has occurred
# Processing records for: malakal
# Processing records for: bathsheba
# Processing records for: san andres
# Processing records for: alta floresta
# Processing records for: taoudenni
# Processing records for: chegdomyn
# Processing records for: koyelga
# An exception has occurred
# Processing records for: arlit
# Processing records for: rio grande
# An exception has occurred
# Processing records for: husavik
# Processing records for: kyra
# Processing records for: naryan-mar
# Processing records for: longyearbyen
# An exception has occurred
# Processing records for: cidreira
# Processing records for: yumen
# Processing records for: provost
# Processing records for: karasjok
# Processing records for: kaitangata
# Processing records for: saskylakh
# Processing records for: hilo
# Processing records for: ushirombo
# Processing records for: hamilton
# Processing records for: olovyannaya
# Processing records for: pacocha
# Processing records for: qaanaaq
# An exception has occurred
# Processing records for: fairbanks
# Processing records for: santa ana
# Processing records for: trincomalee
# Processing records for: worland
# Processing records for: ust-ishim
# Processing records for: hotaka
# Processing records for: ornskoldsvik
# An exception has occurred
# An exception has occurred
# Processing records for: los llanos de aridane
# Processing records for: kodinsk
# Processing records for: khor
# Processing records for: tukums
# Processing records for: camacha
# Processing records for: hidalgo
# Processing records for: victoria
# Processing records for: manzhouli
# Processing records for: ballina
# Processing records for: kavieng
# Processing records for: pontianak
# Processing records for: santiago del estero
# Processing records for: krasnoselkup
# Processing records for: holme
# An exception has occurred
# Processing records for: ossora
# Processing records for: awbari
# Processing records for: kodiak
# Processing records for: dingle
# Processing records for: ikom
# Processing records for: bitung
# Processing records for: pathein
# Processing records for: jacksonville
# Processing records for: tiarei
# Processing records for: sovetskiy
# Processing records for: san isidro
# Processing records for: peniche
# Processing records for: porto novo
# Processing records for: provideniya
# Processing records for: aldan
# Processing records for: torbay
# Processing records for: tambura
# Processing records for: santa fe
# Processing records for: harper
# Processing records for: komsomolskiy
# Processing records for: pangnirtung
# Processing records for: blagoyevo
# Processing records for: monaco-ville
# Processing records for: meulaboh
# Processing records for: mecca
# Processing records for: waipawa
# Processing records for: sakakah
# Processing records for: serenje
# Processing records for: pisco
# Processing records for: vila velha
# Processing records for: luau
# Processing records for: grenfell
# Processing records for: coralville
# Processing records for: shenjiamen
# Processing records for: saint-pierre
# Processing records for: straumen
# Processing records for: natal
# Processing records for: tonj
# Processing records for: kieta
# Processing records for: chunskiy
# Processing records for: sinfra
# Processing records for: seguin
# Processing records for: yefremov
# Processing records for: calvinia
# Processing records for: charagua
# Processing records for: dicabisagan
# Processing records for: yaan
# Processing records for: souillac
# Processing records for: vila
# Processing records for: bairiki
# Processing records for: windhoek
# Processing records for: tura
# Processing records for: bandarbeyla
# Processing records for: san miguelito
# Processing records for: skanderborg
# Processing records for: bilibino
# An exception has occurred
# Processing records for: zhengjiatun
# Processing records for: oranjestad
# Processing records for: santa cruz
# Processing records for: canon city
# Processing records for: odiong
# Processing records for: brae
# Processing records for: serra
# Processing records for: plouzane
# Processing records for: lardos
# Processing records for: sezze
# Processing records for: kavaratti
# Processing records for: tucuma
# Processing records for: kapit
# Processing records for: merauke
# An exception has occurred
# Processing records for: banda
# Processing records for: iralaya
# Processing records for: sohag
# An exception has occurred
# Processing records for: sattahip
# Processing records for: camopi
# Processing records for: coahuayana
# Processing records for: denpasar
# Processing records for: santa isabel do rio negro
# Processing records for: eureka
# Processing records for: presidente epitacio
# Processing records for: karratha
# Processing records for: talnakh
# Processing records for: nioro
# Processing records for: yar-sale
# Processing records for: rennes
# Processing records for: havelock
# Processing records for: pincher creek
# Processing records for: samarai
# Processing records for: kamaishi
# Processing records for: okhotsk
# Processing records for: miles city
# Processing records for: ust-ilimsk
# Processing records for: lagoa
# Processing records for: comodoro rivadavia
# An exception has occurred
# Processing records for: jiaocheng
# Processing records for: taksimo
# Processing records for: kamenka
# Processing records for: guerrero negro
# Processing records for: pevek
# Processing records for: olafsvik
# Processing records for: vanimo
# Processing records for: xiaolan
# Processing records for: chuy
# Processing records for: vanavara
# Processing records for: mount isa
# Processing records for: boshkengash
# Processing records for: arrifes
# Processing records for: rosetta
# Processing records for: pokhara
# Processing records for: hutchinson
# Processing records for: chipinge
# Processing records for: lorengau
# Processing records for: black river
# Processing records for: witu
# Processing records for: kaduy
# Processing records for: leningradskiy
# Processing records for: namatanai
# Processing records for: la rioja
# Processing records for: oktyabrskiy
# Processing records for: acajutla
# Processing records for: necochea
# Processing records for: la ronge
# Processing records for: callaway
# Processing records for: srednekolymsk
# Processing records for: saryozek
# Processing records for: gorontalo
# Processing records for: nuevo laredo
# Processing records for: gari
# Processing records for: ayan
# Processing records for: eston
# Processing records for: mogadishu
# Processing records for: flin flon
# Processing records for: christchurch
# Processing records for: havre-saint-pierre
# An exception has occurred
# Processing records for: shahe
# Processing records for: hirara
# Processing records for: kelme
# Processing records for: kruisfontein
# Processing records for: kununurra
# Processing records for: klaksvik
# Processing records for: rorvik
# Processing records for: tikrit
# Processing records for: marigot
# Processing records for: adrar
# Processing records for: bongandanga
# Processing records for: gushikawa
# Processing records for: mier
# Processing records for: gerash
# Processing records for: abu dhabi
# Processing records for: dogondoutchi
# Processing records for: kerewan
# Processing records for: carrollton
# Processing records for: fare
# Processing records for: mackenzie
# Processing records for: thaba nchu
# Processing records for: meadow lake
# Processing records for: lakes entrance
# Processing records for: wawa
# Processing records for: houma
# Processing records for: werda
# Processing records for: khash
# Processing records for: pacific grove
# Processing records for: fort-shevchenko
# Processing records for: quang ngai
# Processing records for: cubarral
# Processing records for: ulaangom
# Processing records for: pecsvarad
# Processing records for: manica
# Processing records for: sucua
# Processing records for: xihua
# Processing records for: altamira
# Processing records for: buraydah
# Processing records for: dubbo
# Processing records for: zyuzelskiy
# Processing records for: oktyabrskoye
# Processing records for: nador
# Processing records for: igrim
# Processing records for: moose factory
# Processing records for: ust-kulom
# Processing records for: umm lajj
# An exception has occurred
# Processing records for: mukacheve
# Processing records for: mayumba
# Processing records for: leini
# Processing records for: dudinka
# Processing records for: stephenville
# An exception has occurred
# Processing records for: pocone
# Processing records for: oxelosund
# Processing records for: nelson bay
# Processing records for: kandrian
# Processing records for: bolshevik
# Processing records for: grand gaube
# Processing records for: san jeronimo
# Processing records for: bayeux
# Processing records for: aksehir
# Processing records for: pitimbu
# Processing records for: abnub
# Processing records for: los banos
# Processing records for: esmeralda
# Processing records for: touros
# Processing records for: palmer
# Processing records for: kisangani
# Processing records for: hohhot
# Processing records for: vestmannaeyjar
# Processing records for: san patricio
# Processing records for: vardo
# Processing records for: phibun mangsahan
# Processing records for: seymchan
# Processing records for: dungarvan
# Processing records for: fort frances
# Processing records for: aswan
# Processing records for: cumpas
# Processing records for: gambiran
# Processing records for: high level
# Processing records for: deputatskiy
# Processing records for: ankpa
# Processing records for: odweyne
# Processing records for: raudeberg
# Processing records for: cap malheureux
# Processing records for: kuzino
# Processing records for: aksu
# Processing records for: clonakilty
# Processing records for: jaciara
# Processing records for: agadir
# Processing records for: nantucket
# Processing records for: rocha
# Processing records for: whitehorse
# Processing records for: sisimiut
# Processing records for: sheregesh
# Processing records for: san rafael
# Processing records for: jinka
# Processing records for: dunedin
# Processing records for: hervey bay
# Processing records for: tehri
# Processing records for: at-bashi
# Processing records for: svetlyy
# Processing records for: vilhena
# Processing records for: krutinka
# Processing records for: tessalit
# Processing records for: ibipeba
# An exception has occurred
# Processing records for: mandalgovi
# Processing records for: biak
# Processing records for: vasyurinskaya
# Processing records for: valparaiso
# Processing records for: udachnyy
# Processing records for: slave lake
# Processing records for: rawlins
# Processing records for: aracaju
# Processing records for: posse
# Processing records for: preobrazheniye
# An exception has occurred
# Processing records for: kawalu
# Processing records for: curuca
# Processing records for: parsabad
# Processing records for: gamba
# Processing records for: scottsbluff
# An exception has occurred
# Processing records for: taltal
# Processing records for: yangambi
# Processing records for: beloha
# Processing records for: sinnar
# Processing records for: bonavista
# Processing records for: acapulco
# Processing records for: yeghegnut
# Processing records for: tarko-sale
# Processing records for: pinega
# Processing records for: solnechnyy
# Processing records for: lanzhou
# Processing records for: ascension
# Processing records for: xam nua
# An exception has occurred
# Processing records for: te anau
# Processing records for: faanui
# Processing records for: huntsville
# Processing records for: goundam
# An exception has occurred
# Processing records for: sao joao da barra
# Processing records for: nadvoitsy
# Processing records for: dunyapur
# Processing records for: magaria
# Processing records for: pangkalanbuun
# Processing records for: jalu
# Processing records for: dilla
# Processing records for: cabedelo
# Processing records for: brightwater
# Processing records for: lucapa
# Processing records for: morant bay
# Processing records for: roebourne
# Processing records for: rio rancho
# An exception has occurred
# Processing records for: tchollire
# Processing records for: great falls
# Processing records for: buala
# Processing records for: shiyan
# An exception has occurred
# Processing records for: ust-koksa
# Processing records for: castelo branco
# Processing records for: bentiu
# Processing records for: chicama
# Processing records for: myaundzha
# Processing records for: kamra
# Processing records for: itarema
# Processing records for: senanga
# Processing records for: aykhal
# Processing records for: riyadh
# Processing records for: burhanpur
# Processing records for: palu
# Processing records for: hami
# Processing records for: finnsnes
# Processing records for: talaya

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
df = pd.DataFrame({"CityName": CityName, "Latitude": Latitude,
                   "Longitude": Longitude, "MaxTemp": MaxTemp, 
                   "Humidity": Humidity, "Cloudiness": Cloudiness, 
                   "WindSpeed": WindSpeed, "Country": Country, "Date": Date})

# %%
df.to_csv('../Output_Data/weatherpy.csv')

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#None of my cities had humidity over 100%

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
plt.scatter(df['Latitude'], df['MaxTemp'])
plt.grid()
plt.ylabel("Max Temperature (F)")
plt.xlabel("City Latitude")
plt.title("City Latitude vs. Max Temperature")
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.scatter(df['Latitude'], df['Humidity'])
plt.grid()
plt.ylabel("Humidity (%)")
plt.xlabel("City Latitude")
plt.title("City Latitude vs. Humidity")
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.scatter(df['Latitude'], df['Cloudiness'])
plt.grid()
plt.ylabel("Cloudiness (%)")
plt.xlabel("City Latitude")
plt.title("City Latitude vs. Cloudiness")
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.scatter(df['Latitude'], df['WindSpeed'])
plt.grid()
plt.ylabel("Wind Speed (mph)")
plt.xlabel("City Latitude")
plt.title("City Latitude vs. Wind Speed")
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# Create Northern and Southern Hemisphere DataFrames

# %%
north = df.loc[df["Latitude"]>=0]
south = df.loc[df["Latitude"]<0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = north['Latitude']
y_values = north['MaxTemp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,45),fontsize=15,color="red")
plt.xlabel('City Latitude')
plt.ylabel('Max Temperature (F)')
plt.title("City Latitude vs. Max Temperature (Northern Hemisphere)")
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.4333272333751065

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = south['Latitude']
y_values = south['MaxTemp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-55,80),fontsize=15,color="red")
plt.xlabel('City Latitude')
plt.ylabel('Max Temperature (F)')
plt.title("City Latitude vs. Max Temperature (Southern Hemisphere)")
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.6690884704615911

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = north['Latitude']
y_values = north['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(55,20),fontsize=10,color="red")
plt.xlabel('City Latitude')
plt.ylabel('Humidity (%)')
plt.title("City Latitude vs. Humidity (Northern Hemisphere)")
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.004596011848831707

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = south['Latitude']
y_values = south['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-55,60),fontsize=13,color="red")
plt.xlabel('City Latitude')
plt.ylabel('Humidity (%)')
plt.title("City Latitude vs. Humidity (Southern Hemisphere)")
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.022205526735569393

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = north['Latitude']
y_values = north['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(25,57),fontsize=10,color="red")
plt.xlabel('City Latitude')
plt.ylabel('Cloudiness (%)')
plt.title("City Latitude vs. Cloudiness (Northern Hemisphere)")
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.00024161269496565587

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = south['Latitude']
y_values = south['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-40,42),fontsize=10,color="red")
plt.xlabel('City Latitude')
plt.ylabel('Cloudiness (%)')
plt.title("City Latitude vs. Cloudiness (Southern Hemisphere)")
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 3.1556815392397994e-06

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = north['Latitude']
y_values = north['WindSpeed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(20,42),fontsize=10,color="red")
plt.xlabel('City Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title("City Latitude vs. Wind Speed (Northern Hemisphere)")
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.0025592103270572148

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = south['Latitude']
y_values = south['WindSpeed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-55,16),fontsize=10,color="red")
plt.xlabel('City Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title("City Latitude vs. Wind Speed (Southern Hemisphere)")
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.01226690585708846
